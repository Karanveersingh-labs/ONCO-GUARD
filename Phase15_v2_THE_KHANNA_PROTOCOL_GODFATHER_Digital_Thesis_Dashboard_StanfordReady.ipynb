# %% [markdown]
# <a href="https://colab.research.google.com/github/Karanveersingh-labs/ONCO-GUARD/blob/main/Phase15_v2_THE_KHANNA_PROTOCOL_GODFATHER_Digital_Thesis_Dashboard_StanfordReady.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Phase15 v2.0 GODFATHER - Comprehensive Digital Thesis Dashboard - THE KHANNA PROTOCOL
# ### Author: Karanveer Singh - ONCO-GUARD Grand Finale (Phase 1-15 Compilation)
# ### Objective: Radar, Heatmap, Executive Summary - Visual proof of KRAS Master Hub inhibition
# ### Database: STRING-db v12.0, Lipinski, AutoDock, 95.2% ML Model
# ### Significance: Final GODFATHER Thesis Figure - Publication & Patent Ready - 16/16 Stanford Portfolio Locked

# %%
# Phase15 v2.0 GODFATHER - Grand Finale Dashboard - FIXED
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import numpy as np
plt.close('all')
sns.set(style="whitegrid")

params = {"Lipinski":100, "Docking":95, "EE%":95.2, "ADMET":92, "Network":99, "Toxicity":90}
df = pd.DataFrame(list(params.items()), columns=['Parameter','Score'])
print(df.to_string(index=False))

fig = plt.figure(figsize=(16,10))
fig.suptitle('ONCO-GUARD: The Khanna Protocol - Phase15 v2 GODFATHER Dashboard\nKaranveer Singh - StanfordReady', fontweight='bold', fontsize=14)

ax1 = plt.subplot2grid((2,3),(0,0))
sns.barplot(x='Parameter', y='Score', data=df, palette='viridis', ax=ax1)
ax1.set_title('Overall Project Scores (%)', fontweight='bold')
ax1.tick_params(axis='x', rotation=20)

ax2 = plt.subplot2grid((2,3),(0,1))
heat_data = np.array([[0.999,0.998,0.95],[0.92,0.995,0.99],[0.999,0.998,1.0]])
sns.heatmap(heat_data, annot=True, cmap='Reds', ax=ax2)
ax2.set_title('STRING Scores Heatmap', fontweight='bold')

ax3 = plt.subplot2grid((2,3),(0,2), polar=True)
labels = list(params.keys())
values = list(params.values())
values += values[:1]
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]
ax3.plot(angles, values, linewidth=3)
ax3.fill(angles, values, alpha=0.4)
ax3.set_thetagrids(np.degrees(angles[:-1]), labels)
ax3.set_title('Drug Likeness Radar', fontweight='bold')

ax4 = plt.subplot2grid((2,3),(1,0), colspan=3)
ax4.axis('off')
summary = """EXECUTIVE SUMMARY - ONCO-GUARD: The Khanna Protocol (15 Phases - 16 Notebooks)
Author: Karanveer Singh | KRAS = Master Hub (Degree=4, Betweenness=0.633)
Result: Best Candidate - Lipinski 100%, Docking -10.2 kcal/mol, 95.2% ML Accuracy, Low Toxicity
Conclusion: Complete In-Silico Blueprint & IP Ready for Wet Lab - 16/16 COMPLETE - StanfordReady LOCKED
"""
ax4.text(0.5, 0.5, summary, ha='center', va='center', fontsize=11, fontweight='bold', bbox=dict(boxstyle="round,pad=0.8", facecolor="lightcyan", edgecolor="black", linewidth=1.5))

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('Phase15_v2_GODFATHER_Grand_Dashboard_StanfordReady.png', dpi=300)
plt.show()
print("Phase15 v2.0 GODFATHER DONE - 16/16 COMPLETE - Portfolio LOCKED!")
# Out:
# Parameter  Score
#  Lipinski  100.0
#   Docking   95.0
#       EE%   95.2
#     ADMET   92.0
#   Network   99.0
#  Toxicity   90.0
# /tmp/ipykernel_769/1944310225.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Parameter', y='Score', data=df, palette='viridis', ax=ax1)
# Phase15 v2.0 GODFATHER DONE - 16/16 COMPLETE - Portfolio LOCKED!
